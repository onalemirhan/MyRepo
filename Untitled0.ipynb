# %% [markdown]
# <a href="https://colab.research.google.com/github/onalemirhan/MyRepo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World! I am an IPython programmer!")
# Out:
# Hello, World! I am an IPython programmer!
